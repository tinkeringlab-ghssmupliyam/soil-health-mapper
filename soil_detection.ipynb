# %% [markdown]
# <a href="https://colab.research.google.com/github/tinkeringlab-ghssmupliyam/soil-health-mapper/blob/main/soil_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 ! pip install ultralytics

# %%
# !kaggle datasets download tinkeringlabmupliyam/soil-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/tinkeringlabmupliyam/soil-dataset
# License(s): unknown
# soil-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip -qq /content/soil-dataset.zip
# Out:
# replace README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace data.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace test/images/-102-_jpg.rf.436869992f59b26209b8af3abf5287e5.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
# !yolo train model=yolo12n.pt data=/content/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
